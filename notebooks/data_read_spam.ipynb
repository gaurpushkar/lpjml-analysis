# %%
import pandas as pd
import os

# %%
base = os.path.join(os.getcwd(),'..','data(LPJmL)')

# %%
data = pd.read_csv(os.path.join(base,'LPJ_MAPSPAM2020_FAO_17crops.csv'),delimiter=';')

# %%
data.to_excel(os.path.join(base,'MAPSPMA_rename.xlsx'))
